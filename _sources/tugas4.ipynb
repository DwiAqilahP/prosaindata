# %% [markdown]
# # **Tugas 2 Pipelines**

# %% [markdown]
# ## **Mengambil data dari database postgreSQL elephant**

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\asus\anaconda3\lib\site-packages (2.9.5)

# %%
import psycopg2
import pandas as pd
# Connection parameters, yours will be different
param_dic = {
    "host"      : "floppy.db.elephantsql.com",
    "database"  : "puvnoauz",
    "user"      : "puvnoauz",
    "password"  : "hj_z1oYB1XJldeOLCfI14w6Yqe8cdcIM"
}
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

def postgresql_to_dataframe(conn, select_query, column_names):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df

# Connect to the database
conn = connect(param_dic)

column_names = ["id","sepalwidh"]

df_post_e = postgresql_to_dataframe(conn, "select * from puvnoauz", column_names)
print(df_post_e )
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#       id sepalwidh
# 0      1       3.5
# 1      2       3.0
# 2      3       3.2
# 3      4       3.1
# 4      5       3.6
# ..   ...       ...
# 145  146       3.0
# 146  147       2.5
# 147  148       3.0
# 148  149       3.4
# 149  150       3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# ## **Mengambil data dari database localhost**

# %%
# !pip install mysqlclient
# !pip install mysql-connector-python
# !pip install pymysql
# Out:
# Requirement already satisfied: mysqlclient in c:\users\asus\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: mysql-connector-python in c:\users\asus\anaconda3\lib\site-packages (8.0.32)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in c:\users\asus\anaconda3\lib\site-packages (from mysql-connector-python) (3.20.3)
# Requirement already satisfied: pymysql in c:\users\asus\anaconda3\lib\site-packages (1.0.2)

# %%
import mysql.connector
import pandas as pd

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="petal_length"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM iris")

myresult = mycursor.fetchall()
mycursor.close()
df_mysql = pd.DataFrame(myresult, columns=['id','petallength'])
# df_mysql.drop(df_mysql.columns[[0]],axis=1,inplace=True)
df_mysql
# Out:
#       id petallength
# 0      1         1.4
# 1      2         1.4
# 2      3         1.3
# 3      4         1.5
# 4      5         1.4
# ..   ...         ...
# 145  146         5.2
# 146  147         5.0
# 147  148         5.2
# 148  149         5.4
# 149  150         5.1
#
# [150 rows x 2 columns]

# %% [markdown]
# ## **Mengambil data dari database SQL Server**

# %%
# !pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\asus\anaconda3\lib\site-packages (4.0.34)

# %%
import pyodbc 
import pandas as pd
cnxn_str = ("Driver={odbc driver 17 for sql server};"
            "Server=DESKTOP-4JAN520\SQLEXPRESS;"
            "Database=petal_w;"
            "Trusted_Connection=yes;")
cnxn = pyodbc.connect(cnxn_str)
cursor = cnxn.cursor()	
cursor.execute("SELECT * FROM dbo.petal_w") 
row = cursor.fetchall() 
cursor.close()
data=[]
for i in row:
    data.append([i[0].strip('"'),i[1].strip('"'),i[2]])
df_sqlServer = pd.DataFrame(data, columns=['id','petalwidth','class'])
df_sqlServer
# Out:
#       id petalwidth             class
# 0      1        0.2     "Iris-setosa"
# 1      2        0.2     "Iris-setosa"
# 2      3        0.2     "Iris-setosa"
# 3      4        0.2     "Iris-setosa"
# 4      5        0.2     "Iris-setosa"
# ..   ...        ...               ...
# 145  146        2.3  "Iris-virginica"
# 146  147        1.9  "Iris-virginica"
# 147  148        2.0  "Iris-virginica"
# 148  149        2.3  "Iris-virginica"
# 149  150        1.8  "Iris-virginica"
#
# [150 rows x 3 columns]

# %% [markdown]
# ## **Mengambil data dari database Postgres Local**

# %%
import psycopg2
import pandas as pd
# Connection parameters, yours will be different
param_dic = {
    "host"      : "localhost",
    "database"  : "sepal_l",
    "user"      : "postgres",
    "password"  : "postgres"
}
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

def postgresql_to_dataframe(conn, select_query, column_names):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df

# Connect to the database
conn = connect(param_dic)

column_names = ["id","sepal_l"]

df_post_local = postgresql_to_dataframe(conn, "select * from sepal_l", column_names)
print(df_post_local)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#       id sepal_l
# 0      1     5.1
# 1      2     4.9
# 2      3     4.7
# 3      4     4.6
# 4      5     5.0
# ..   ...     ...
# 145  146     6.7
# 146  147     6.3
# 147  148     6.5
# 148  149     6.2
# 149  150     5.9
#
# [150 rows x 2 columns]

# %% [markdown]
# ## **Menggabungkan Empat Sumber data**

# %%
# merge df
result = pd.concat([df_post_local, df_post_e,df_mysql, df_sqlServer], axis=1)
# result = pd.merge(df_post_local,df_sqlServer, how="inner", on=["id", "id"])
result
# Out:
#       id sepal_l   id sepalwidh   id petallength   id petalwidth  \
# 0      1     5.1    1       3.5    1         1.4    1        0.2
# 1      2     4.9    2       3.0    2         1.4    2        0.2
# 2      3     4.7    3       3.2    3         1.3    3        0.2
# 3      4     4.6    4       3.1    4         1.5    4        0.2
# 4      5     5.0    5       3.6    5         1.4    5        0.2
# ..   ...     ...  ...       ...  ...         ...  ...        ...
# 145  146     6.7  146       3.0  146         5.2  146        2.3
# 146  147     6.3  147       2.5  147         5.0  147        1.9
# 147  148     6.5  148       3.0  148         5.2  148        2.0
# 148  149     6.2  149       3.4  149         5.4  149        2.3
# 149  150     5.9  150       3.0  150         5.1  150        1.8
#
#                 class
# 0       "Iris-setosa"
# 1       "Iris-setosa"
# 2       "Iris-setosa"
# 3       "Iris-setosa"
# 4       "Iris-setosa"
# ..                ...
# 145  "Iris-virginica"
# 146  "Iris-virginica"
# 147  "Iris-virginica"
# 148  "Iris-virginica"
# 149  "Iris-virginica"
#
# [150 rows x 9 columns]

# %%
result.drop(result.columns[[0,2,4,6]],axis=1,inplace=True)
result
# Out:
#     sepal_l sepalwidh petallength petalwidth             class
# 0       5.1       3.5         1.4        0.2     "Iris-setosa"
# 1       4.9       3.0         1.4        0.2     "Iris-setosa"
# 2       4.7       3.2         1.3        0.2     "Iris-setosa"
# 3       4.6       3.1         1.5        0.2     "Iris-setosa"
# 4       5.0       3.6         1.4        0.2     "Iris-setosa"
# ..      ...       ...         ...        ...               ...
# 145     6.7       3.0         5.2        2.3  "Iris-virginica"
# 146     6.3       2.5         5.0        1.9  "Iris-virginica"
# 147     6.5       3.0         5.2        2.0  "Iris-virginica"
# 148     6.2       3.4         5.4        2.3  "Iris-virginica"
# 149     5.9       3.0         5.1        1.8  "Iris-virginica"
#
# [150 rows x 5 columns]

# %%
X = result.values[:, :4]
Y = result.values[:, 4]
print(X)
# Out:
# [[Decimal('5.1') Decimal('3.5') Decimal('1.4') '0.2']
#  [Decimal('4.9') Decimal('3.0') Decimal('1.4') '0.2']
#  [Decimal('4.7') Decimal('3.2') Decimal('1.3') '0.2']
#  [Decimal('4.6') Decimal('3.1') Decimal('1.5') '0.2']
#  [Decimal('5.0') Decimal('3.6') Decimal('1.4') '0.2']
#  [Decimal('5.4') Decimal('3.9') Decimal('1.7') '0.4']
#  [Decimal('4.6') Decimal('3.4') Decimal('1.4') '0.3']
#  [Decimal('5.0') Decimal('3.4') Decimal('1.5') '0.2']
#  [Decimal('4.4') Decimal('2.9') Decimal('1.4') '0.2']
#  [Decimal('4.9') Decimal('3.1') Decimal('1.5') '0.1']
#  [Decimal('5.4') Decimal('3.7') Decimal('1.5') '0.2']
#  [Decimal('4.8') Decimal('3.4') Decimal('1.6') '0.2']
#  [Decimal('4.8') Decimal('3.0') Decimal('1.4') '0.1']
#  [Decimal('4.3') Decimal('3.0') Decimal('1.1') '0.1']
#  [Decimal('5.8') Decimal('4.0') Decimal('1.2') '0.2']
#  [Decimal('5.7') Decimal('4.4') Decimal('1.5') '0.4']
#  [Decimal('5.4') Decimal('3.9') Decimal('1.3') '0.4']
#  [Decimal('5.1') Decimal('3.5') Decimal('1.4') '0.3']
#  [Decimal('5.7') Decimal('3.8') Decimal('1.7') '0.3']
#  [Decimal('5.1') Decimal('3.8') Decimal('1.5') '0.3']
#  [Decimal('5.4') Decimal('3.4') Decimal('1.7') '0.2']
#  [Decimal('5.1') Decimal('3.7') Decimal('1.5') '0.4']
#  [Decimal('4.6') Decimal('3.6') Decimal('1.0') '0.2']
#  [Decimal('5.1') Decimal('3.3') Decimal('1.7') '0.5']
#  [Decimal('4.8') Decimal('3.4') Decimal('1.9') '0.2']
#  [Decimal('5.0') Decimal('3.0') Decimal('1.6') '0.2']
#  [Decimal('5.0') Decimal('3.4') Decimal('1.6') '0.4']
#  [Decimal('5.2') Decimal('3.5') Decimal('1.5') '0.2']
#  [Decimal('5.2') Decimal('3.4') Decimal('1.4') '0.2']
#  [Decimal('4.7') Decimal('3.2') Decimal('1.6') '0.2']
#  [Decimal('4.8') Decimal('3.1') Decimal('1.6') '0.2']
#  [Decimal('5.4') Decimal('3.4') Decimal('1.5') '0.4']
#  [Decimal('5.2') Decimal('4.1') Decimal('1.5') '0.1']
#  [Decimal('5.5') Decimal('4.2') Decimal('1.4') '0.2']
#  [Decimal('4.9') Decimal('3.1') Decimal('1.5') '0.1']
#  [Decimal('5.0') Decimal('3.2') Decimal('1.2') '0.2']
#  [Decimal('5.5') Decimal('3.5') Decimal('1.3') '0.2']
#  [Decimal('4.9') Decimal('3.1') Decimal('1.5') '0.1']
#  [Decimal('4.4') Decimal('3.0') Decimal('1.3') '0.2']
#  [Decimal('5.1') Decimal('3.4') Decimal('1.5') '0.2']
#  [Decimal('5.0') Decimal('3.5') Decimal('1.3') '0.3']
#  [Decimal('4.5') Decimal('2.3') Decimal('1.3') '0.3']
#  [Decimal('4.4') Decimal('3.2') Decimal('1.3') '0.2']
#  [Decimal('5.0') Decimal('3.5') Decimal('1.6') '0.6']
#  [Decimal('5.1') Decimal('3.8') Decimal('1.9') '0.4']
#  [Decimal('4.8') Decimal('3.0') Decimal('1.4') '0.3']
#  [Decimal('5.1') Decimal('3.8') Decimal('1.6') '0.2']
#  [Decimal('4.6') Decimal('3.2') Decimal('1.4') '0.2']
#  [Decimal('5.3') Decimal('3.7') Decimal('1.5') '0.2']
#  [Decimal('5.0') Decimal('3.3') Decimal('1.4') '0.2']
#  [Decimal('7.0') Decimal('3.2') Decimal('4.7') '1.4']
#  [Decimal('6.4') Decimal('3.2') Decimal('4.5') '1.5']
#  [Decimal('6.9') Decimal('3.1') Decimal('4.9') '1.5']
#  [Decimal('5.5') Decimal('2.3') Decimal('4.0') '1.3']
#  [Decimal('6.5') Decimal('2.8') Decimal('4.6') '1.5']
#  [Decimal('5.7') Decimal('2.8') Decimal('4.5') '1.3']
#  [Decimal('6.3') Decimal('3.3') Decimal('4.7') '1.6']
#  [Decimal('4.9') Decimal('2.4') Decimal('3.3') '1.0']
#  [Decimal('6.6') Decimal('2.9') Decimal('4.6') '1.3']
#  [Decimal('5.2') Decimal('2.7') Decimal('3.9') '1.4']
#  [Decimal('7.3') Decimal('2.9') Decimal('6.3') '1.8']
#  [Decimal('6.7') Decimal('2.5') Decimal('5.8') '1.8']
#  [Decimal('7.2') Decimal('3.6') Decimal('6.1') '2.5']
#  [Decimal('6.5') Decimal('3.2') Decimal('5.1') '2.0']
#  [Decimal('6.4') Decimal('2.7') Decimal('5.3') '1.9']
#  [Decimal('6.8') Decimal('3.0') Decimal('5.5') '2.1']
#  [Decimal('5.7') Decimal('2.5') Decimal('5.0') '2.0']
#  [Decimal('5.8') Decimal('2.8') Decimal('5.1') '2.4']
#  [Decimal('6.4') Decimal('3.2') Decimal('5.3') '2.3']
#  [Decimal('6.5') Decimal('3.0') Decimal('5.5') '1.8']
#  [Decimal('7.7') Decimal('3.8') Decimal('6.7') '2.2']
#  [Decimal('7.7') Decimal('2.6') Decimal('6.9') '2.3']
#  [Decimal('6.0') Decimal('2.2') Decimal('5.0') '1.5']
#  [Decimal('6.9') Decimal('3.2') Decimal('5.7') '2.3']
#  [Decimal('5.6') Decimal('2.8') Decimal('4.9') '2.0']
#  [Decimal('7.7') Decimal('2.8') Decimal('6.7') '2.0']
#  [Decimal('6.3') Decimal('2.7') Decimal('4.9') '1.8']
#  [Decimal('6.7') Decimal('3.3') Decimal('5.7') '2.1']
#  [Decimal('7.2') Decimal('3.2') Decimal('6.0') '1.8']
#  [Decimal('6.2') Decimal('2.8') Decimal('4.8') '1.8']
#  [Decimal('6.1') Decimal('3.0') Decimal('4.9') '1.8']
#  [Decimal('6.4') Decimal('2.8') Decimal('5.6') '2.1']
#  [Decimal('7.2') Decimal('3.0') Decimal('5.8') '1.6']
#  [Decimal('7.4') Decimal('2.8') Decimal('6.1') '1.9']
#  [Decimal('7.9') Decimal('3.8') Decimal('6.4') '2.0']
#  [Decimal('6.4') Decimal('2.8') Decimal('5.6') '2.2']
#  [Decimal('6.3') Decimal('2.8') Decimal('5.1') '1.5']
#  [Decimal('6.1') Decimal('2.6') Decimal('5.6') '1.4']
#  [Decimal('7.7') Decimal('3.0') Decimal('6.1') '2.3']
#  [Decimal('6.3') Decimal('3.4') Decimal('5.6') '2.4']
#  [Decimal('6.4') Decimal('3.1') Decimal('5.5') '1.8']
#  [Decimal('6.0') Decimal('3.0') Decimal('4.8') '1.8']
#  [Decimal('6.9') Decimal('3.1') Decimal('5.4') '2.1']
#  [Decimal('6.7') Decimal('3.1') Decimal('5.6') '2.4']
#  [Decimal('6.9') Decimal('3.1') Decimal('5.1') '2.3']
#  [Decimal('5.8') Decimal('2.7') Decimal('5.1') '1.9']
#  [Decimal('6.8') Decimal('3.2') Decimal('5.9') '2.3']
#  [Decimal('6.7') Decimal('3.3') Decimal('5.7') '2.5']
#  [Decimal('6.7') Decimal('3.0') Decimal('5.2') '2.3']
#  [Decimal('6.3') Decimal('2.5') Decimal('5.0') '1.9']
#  [Decimal('6.5') Decimal('3.0') Decimal('5.2') '2.0']
#  [Decimal('6.2') Decimal('3.4') Decimal('5.4') '2.3']
#  [Decimal('5.9') Decimal('3.0') Decimal('5.1') '1.8']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( 
    X, Y, test_size = 0.2, random_state = 100)

# %% [markdown]
# ## **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print (" DecisionTree Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
# Out:
#  DecisionTree Accuracy :  96.66666666666667

# %% [markdown]
# ## **KNeighbors Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
print (" KNN Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
# Out:
#  KNN Accuracy :  100.0
